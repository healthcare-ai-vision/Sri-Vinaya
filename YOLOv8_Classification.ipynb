# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
print("YOLO installed successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO installed successfully

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")
model.train(data="cifar10", epochs=10)
# Out:
# ...
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !find /content/datasets/cifar10/test -type f | head -n 5
# Out:
# /content/datasets/cifar10/test/deer/0066.png
# /content/datasets/cifar10/test/deer/0350.png
# /content/datasets/cifar10/test/deer/0167.png
# /content/datasets/cifar10/test/deer/0548.png
# /content/datasets/cifar10/test/deer/0042.png

# %%
model.predict(
    source="/content/datasets/cifar10/test/deer/0042.png",
    save=True
)
# Out:
# image 1/1 /content/datasets/cifar10/test/deer/0042.png: 224x224 deer 1.00, dog 0.00, cat 0.00, bird 0.00, frog 0.00, 4.0ms
# Speed: 4.1ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}
#  obb: None
#  orig_img: array([[[ 59,  78,  56],
#          [ 53,  71,  50],
#          [ 54,  72,  54],
#          ...,
#          [ 70,  87,  94],
#          [ 73,  87,  94],
#          [ 60,  73,  78]],
#
#         [[ 55,  72,  51],
#          [ 49,  65,  48],
#          [ 44,  57,  47],
#          ...,
#          [ 61,  81,  84],
#          [ 62,  79,  84],
#          [ 74,  89,  96]],
#
#         [[ 59,  72,  58],
#          [ 54,  67,  55],
#          [ 49,  60,  51],
# ...

# %%
model.predict(
    source="/content/datasets/cifar10/test/deer/0167.png",
    save=True
)
# Out:
# image 1/1 /content/datasets/cifar10/test/deer/0167.png: 224x224 deer 1.00, bird 0.00, horse 0.00, cat 0.00, dog 0.00, 2.9ms
# Speed: 3.0ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}
#  obb: None
#  orig_img: array([[[ 53,  79,  76],
#          [ 42,  72,  63],
#          [ 19,  52,  45],
#          ...,
#          [ 68,  91,  84],
#          [ 50,  73,  68],
#          [ 52,  73,  71]],
#
#         [[ 53,  80,  75],
#          [ 43,  75,  64],
#          [ 33,  67,  58],
#          ...,
#          [ 68,  93,  86],
#          [ 47,  75,  69],
#          [ 48,  75,  72]],
#
#         [[ 51,  79,  72],
#          [ 48,  80,  67],
#          [ 49,  83,  73],
# ...
